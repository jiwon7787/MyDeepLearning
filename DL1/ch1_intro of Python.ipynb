# %%
import numpy as np

# %%
1 + 1
# Out:
# 2

# %%
1 - 2
4 * 5
7 / 5
3**2
# Out:
# 9

# %%
type(10)
# Out:
# int

# %%
type(2.14)
# Out:
# float

# %%
type("hello")
# Out:
# str

# %%
x = 10
print(x)
# Out:
# 10

# %%
a = [1, 2, 3, 4, 5]
print(a)
print(len(a))
print("hello")
print(a[3])
a[3] = 99
print(a[3])
print(a)
print(a[0:2])
print(a[1:])
print(a[:3])
print(a[:-1])
print(a[:-2])
# Out:
# [1, 2, 3, 4, 5]
# 5
# hello
# 4
# 99
# [1, 2, 3, 99, 5]
# [1, 2]
# [2, 3, 99, 5]
# [1, 2, 3]
# [1, 2, 3, 99]
# [1, 2, 3]

# %%
me = {"height": 180}
me["weight"] = 70
print(me["height"])
print(me["weight"])
print(me)
# Out:
# 180
# 70
# {'height': 180, 'weight': 70}

# %%
hungry = True
sleepy = False
not hungry
# Out:
# False

# %%
def hello():
    print("hello jiwon")


hello()
# Out:
# hello jiwon

# %%
class Man:
    def __init__(self, name):
        """_summary_

        Args:
            name (_type_): _description_
        """
        self.name = name
        print("Initialized!")

    def hello(self):
        print("Hello " + self.name + "!")


m = Man("Jiwon")
m.hello()
# Out:
# Initialized!
# Hello Jiwon!

# %%
x = np.array([1.0, 2.0, 3.0])
print(x)
y = np.array([2.0, 4.0, 6.0])
print(y)
print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x / 2.0)
# Out:
# [1. 2. 3.]
# [2. 4. 6.]
# [3. 6. 9.]
# [-1. -2. -3.]
# [ 2.  8. 18.]
# [0.5 0.5 0.5]
# [0.5 1.  1.5]

# %%
A = np.array([[1, 2], [3, 4]])
print(A)
print(A.shape)
print(A.dtype)

B = np.array([[3, 0], [0, 6]])
print(A + B)
print(A * B)

print(A * 10)

C = np.array([10, 20])
print(A * C)
# Out:
# [[1 2]
#  [3 4]]
# (2, 2)
# int32
# [[ 4  2]
#  [ 3 10]]
# [[ 3  0]
#  [ 0 24]]
# [[10 20]
#  [30 40]]
# [[10 40]
#  [30 80]]

# %%
X = np.array([[51, 55], [14, 19], [0, 4]])
print(X)
print(X[0])
print(X[0][1])

for row in X:
    print(row)

X = X.flatten()
print(X)
print(X[np.array([0, 2, 4])])
print(X[0], X[2], X[4])

print(X > 15)
print(X[X > 15])
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]
# [51 55]
# 55
# [51 55]
# [14 19]
# [0 4]
# [51 55 14 19  0  4]
# [51 14  0]
# 51 14 0
# [ True  True False  True False False]
# [51 55 19]

# %%
import matplotlib.pyplot as plt

x = np.arange(0, 6, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x, y1, label="sin")
plt.plot(x, y2, linestyle="--", label="cos")

plt.xlabel("x")
plt.ylabel("y")
plt.title("sin & cos")

plt.legend()
plt.show()

# %%
from matplotlib.image import imread

img_path = r"C:\Users\jiwon\OneDrive\Pictures\asus.jpg"  # raw 文字列として指定する
img = imread(img_path)
plt.imshow(img)

plt.show()
